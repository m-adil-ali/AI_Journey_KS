# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing data
import pandas as pd

df = pd.read_csv("F:\Aampotnt_files\KS_AI_Journey\AI_Journey_KS\Week_3\Day_5\IT Salary Survey EU  2020.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
df.columns.value_counts().sum()
# Out:
# 23

# %%
df['Years of experience in Germany'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1253 entries, 0 to 1252
# Series name: Years of experience in Germany
# Non-Null Count  Dtype
# --------------  -----
# 1221 non-null   object
# dtypes: object(1)
# memory usage: 9.9+ KB

# %%
df1 = df.copy()
df1.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
#print(f"Null values before: {df1['Years of experience in Germany'].isnull().sum()}")
df1['Years of experience in Germany'].fillna(99, inplace=True)
# print('After')
# df1['Years of experience in Germany'].isnull().sum()
# Out:
# C:\Users\Asim Mehdi\AppData\Local\Temp\ipykernel_15344\2597147940.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Years of experience in Germany'].fillna(99, inplace=True)

# %%
df1['Years of experience in Germany'].unique()
# Out:
# array(['3', '4', '6', '1', '0.4', '2', '11', 99, '5', '9', '30', '7',
#        '15', '10', '18', '0', '8', '2.5', '1,5', '1.5', '0.5', '13', '14',
#        '4,5', '3.5', '0.8', '1,7', '12', '3,5', '20', '0.9', '25', '< 1',
#        '0.25', '4 (in Switzerland), 0 (in Germany)', '16', '17',
#        '4 month', '19', '2,5', '0,5', '26', '3 months', '4.5', '0.1',
#        '2.6', '3 (in Poland)', '<1', '⁰', '0,3', '-',
#        '6 (not as a data scientist, but as a lab scientist)', '0.2',
#        'less than year'], dtype=object)

# %%
del_list = [ '< 1','4 (in Switzerland), 0 (in Germany)', '<1' ,'4 month', '3 months' , '3 (in Poland)', '⁰','-',
            '6 (not as a data scientist, but as a lab scientist)', 'less than year']

df1 = df1[~df1['Years of experience in Germany'].isin(del_list)]

df1['Years of experience in Germany'].unique()
# Out:
# array(['3', '4', '6', '1', '0.4', '2', '11', 99, '5', '9', '30', '7',
#        '15', '10', '18', '0', '8', '2.5', '1,5', '1.5', '0.5', '13', '14',
#        '4,5', '3.5', '0.8', '1,7', '12', '3,5', '20', '0.9', '25', '0.25',
#        '16', '17', '19', '2,5', '0,5', '26', '4.5', '0.1', '2.6', '0,3',
#        '0.2'], dtype=object)

# %%
# replcing , with . to make the column float type
df1['Years of experience in Germany'] = df1['Years of experience in Germany'].str.replace(',', '.')
df1['Years of experience in Germany'].unique()
# Out:
# array(['3', '4', '6', '1', '0.4', '2', '11', nan, '5', '9', '30', '7',
#        '15', '10', '18', '0', '8', '2.5', '1.5', '0.5', '13', '14', '4.5',
#        '3.5', '0.8', '1.7', '12', '20', '0.9', '25', '0.25', '16', '17',
#        '19', '26', '0.1', '2.6', '0.3', '0.2'], dtype=object)

# %%
df1['Years of experience in Germany'] = df1['Years of experience in Germany'].astype(float)
df1['Years of experience in Germany'].dtype
# Out:
# dtype('float64')

# %%
df1['Years of experience in Germany'] = df1['Years of experience in Germany'].replace(99, 3.72) # 3.72 is the mean of this column

# %% [markdown]
# - Now my data of related to "experience in Germany" is clean enough to answer the 1st question.
# - Answer (a)

# %%
df1[df1['Years of experience in Germany'] > 5].loc[::]
# Out:
#                 Timestamp   Age Gender         City            Position   \
# 2     24/11/2020 11:14:21  29.0   Male       Berlin    Software Engineer
# 4     24/11/2020 11:15:46  37.0   Male       Berlin    Backend Developer
# 11    24/11/2020 11:18:16   NaN   Male       Berlin    Software Engineer
# 21    24/11/2020 11:21:18  34.0   Male       Berlin   Software Architect
# 23    24/11/2020 11:23:11  59.0   Male       Berlin    Backend Developer
# ...                   ...   ...    ...          ...                  ...
# 1230  08/01/2021 00:38:57  35.0   Male    Karlsruhe    Software Engineer
# 1232  08/01/2021 16:12:36  52.0   Male    Stuttgart    Software Engineer
# 1242  16/01/2021 14:39:02  32.0   Male       Munich       ERP Consultant
# 1246  18/01/2021 09:51:30  38.0   Male       Berlin  Head of Engineering
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken   Frontend Developer
#
#      Total years of experience  Years of experience in Germany  \
# ...

# %% [markdown]
# - Answer (b)

# %%
df1.iloc[:10]
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
# 5  24/11/2020 11:15:53  32.0   Male  Berlin              DevOps
# 6  24/11/2020 11:16:35  37.0   Male  Berlin  Frontend Developer
# 7  24/11/2020 11:16:44  24.0   Male  Berlin  Frontend Developer
# 8  24/11/2020 11:17:24  29.0   Male  Berlin   Backend Developer
# 9  24/11/2020 11:17:50  35.0   Male  Berlin   Software Engineer
#
#   Total years of experience  Years of experience in Germany Seniority level  \
# 0                         5                             3.0          Senior
# 1                         7                             4.0          Senior
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df1.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience  Years of experience in Germany Seniority level  \
# 0                         5                             3.0          Senior
# 1                         7                             4.0          Senior
# 2                        12                             6.0            Lead
# 3                         4                             1.0          Junior
# 4                        17                             6.0          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
cond1 = df1['Company type'] == "Startup"
cond2 = df1['Yearly brutto salary (without bonus and stocks) in EUR'] > 60000

df1[ (cond1) & (cond2)]
# Out:
#                 Timestamp   Age Gender    City           Position   \
# 5     24/11/2020 11:15:53  32.0   Male  Berlin              DevOps
# 13    24/11/2020 11:18:26  34.0   Male  Berlin   Software Engineer
# 17    24/11/2020 11:19:10  41.0   Male  Berlin     Product Manager
# 31    24/11/2020 11:27:34  31.0   Male  Berlin   Backend Developer
# 33    24/11/2020 11:27:49  39.0   Male  Berlin   Software Engineer
# ...                   ...   ...    ...     ...                 ...
# 1224  05/01/2021 23:51:56  31.0   Male  Munich   Backend Developer
# 1227  06/01/2021 21:42:52  34.0   Male  Berlin  Frontend Developer
# 1244  16/01/2021 22:23:04  32.0   Male  Munich   Software Engineer
# 1247  18/01/2021 11:50:02  34.0   Male  Zurich   Software Engineer
# 1252  19/01/2021 12:01:11  26.0   Male  Berlin              DevOps
#
#      Total years of experience  Years of experience in Germany  \
# 5                            5                             1.0
# ...

# %% [markdown]
# - Answer (b)

# %%
df1['Have you lost your job due to the coronavirus outbreak?'].unique()
# Out:
# array(['No', 'Yes',
#        "i didn't but will be looking for new one because of covid", nan,
#        'kurzarbeitzeit for 1.5 months',
#        'Have been a freelancer at the beginning of year',
#        'No, but there was a salary cut at 10% for 3 months and then at 5% for further 3 months',
#        'Lost the job but for different reason',
#        'Leads and project inquiries have slowed down',
#        'yes but found a new one with better pay / perks'], dtype=object)

# %%
# after checking the unique values we can assume only 'yes' and last response must be filterred out.

df1[(df1['Have you lost your job due to the coronavirus outbreak?'] == 'Yes') | 
    (df1['Have you lost your job due to the coronavirus outbreak?'] == 'yes but found a new one with better pay / perks')]
# Out:
#                 Timestamp   Age Gender              City           Position   \
# 2     24/11/2020 11:14:21  29.0   Male            Berlin   Software Engineer
# 11    24/11/2020 11:18:16   NaN   Male            Berlin   Software Engineer
# 14    24/11/2020 11:18:40  28.0   Male            Berlin    Designer (UI/UX)
# 17    24/11/2020 11:19:10  41.0   Male            Berlin     Product Manager
# 25    24/11/2020 11:25:03  38.0   Male            Berlin           Team Lead
# ...                   ...   ...    ...               ...                 ...
# 1221  05/01/2021 22:12:30  44.0   Male            Munich  Software Architekt
# 1234  10/01/2021 22:31:57  26.0   Male  Saint-Petersburg     Project Manager
# 1235  10/01/2021 22:32:12  26.0   Male  Saint-Petersburg     Project Manager
# 1236  11/01/2021 12:12:34  39.0   Male            Berlin         QA Engineer
# 1248  18/01/2021 15:05:50  31.0   Male            Berlin   Backend Developer
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df1['Total years of experience'].unique()
# Out:
# array(['5', '7', '12', '4', '17', '6', '8', '15', '2', '25', nan, '14',
#        '11', '18', '13', '30', '10', '3', '40', '26', '23', '9', '19',
#        '20', '5.5', '22', '16', '0.8', '1', '1.5', '6.5', '21', '7.5',
#        '2.5', '28', '29', '1,5', '24', '0', '4.5', '27',
#        '1 (as QA Engineer) / 11 in total', '2,5', '15, thereof 8 as CTO',
#        '31', '383', '3.5'], dtype=object)

# %%
df1['Total years of experience'] = df1['Total years of experience'].str.replace('1 (as QA Engineer) / 11 in total', '12')
df1['Total years of experience'] = df1['Total years of experience'].str.replace('2,5', '2.5')
df1['Total years of experience'] = df1['Total years of experience'].str.replace('1,5', '1.5')
df1['Total years of experience'] = df1['Total years of experience'].str.replace('15, thereof 8 as CTO', '15')
df1 = df1[df1['Total years of experience'] != '383']


df1['Total years of experience'].unique()
# Out:
# array(['5', '7', '12', '4', '17', '6', '8', '15', '2', '25', nan, '14',
#        '11', '18', '13', '30', '10', '3', '40', '26', '23', '9', '19',
#        '20', '5.5', '22', '16', '0.8', '1', '1.5', '6.5', '21', '7.5',
#        '2.5', '28', '29', '24', '0', '4.5', '27', '31', '3.5'],
#       dtype=object)

# %%
df1['Total years of experience'].fillna(99,inplace= True)

df1['Total years of experience'].unique()
# Out:
# C:\Users\Asim Mehdi\AppData\Local\Temp\ipykernel_15344\2198350106.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Total years of experience'].fillna(99,inplace= True)
# array(['5', '7', '12', '4', '17', '6', '8', '15', '2', '25', 99, '14',
#        '11', '18', '13', '30', '10', '3', '40', '26', '23', '9', '19',
#        '20', '5.5', '22', '16', '0.8', '1', '1.5', '6.5', '21', '7.5',
#        '2.5', '28', '29', '24', '0', '4.5', '27', '31', '3.5'],
#       dtype=object)

# %%
df1['Total years of experience'] = df1['Total years of experience'].astype('float')

# %%
df1['Total years of experience'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Answer (a)

# %%
df1['Experience Difference']  = df1['Total years of experience'] - df1['Years of experience in Germany']
df1['Experience Difference']
# Out:
# 0        2.0
# 1        3.0
# 2        6.0
# 3        3.0
# 4       11.0
#         ...
# 1248     4.0
# 1249     8.5
# 1250    13.0
# 1251     0.0
# 1252     0.0
# Name: Experience Difference, Length: 1242, dtype: float64

# %% [markdown]
# - Answer (b)

# %%
df1.groupby(['City'])['Yearly brutto salary (without bonus and stocks) in EUR'].mean()
# Out:
# City
# Aachen        40082.000000
# Amsterdam     74538.888889
# Ansbach       42000.000000
# Barcelona     31000.000000
# Basel        115000.000000
#                  ...
# Wroclaw       36000.000000
# Würzburg      75000.000000
# Zurich       121625.000000
# Zürich        35000.000000
# warsaw        50000.000000
# Name: Yearly brutto salary (without bonus and stocks) in EUR, Length: 117, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer (a)

# %%
group1 = df1.groupby('City')['Yearly brutto salary (without bonus and stocks) in EUR'].mean()
group1
# Out:
# City
# Aachen        40082.000000
# Amsterdam     74538.888889
# Ansbach       42000.000000
# Barcelona     31000.000000
# Basel        115000.000000
#                  ...
# Wroclaw       36000.000000
# Würzburg      75000.000000
# Zurich       121625.000000
# Zürich        35000.000000
# warsaw        50000.000000
# Name: Yearly brutto salary (without bonus and stocks) in EUR, Length: 117, dtype: float64

# %% [markdown]
# - Answer (b)

# %%
df1.dropna(subset=['Position ', 'Seniority level'], inplace=True)

group2 = df1.groupby('Position ')['Seniority level'].count()
group2
# Out:
# Position
# AI Management                 1
# Account Managet               1
# Agile Coach                   1
# Analyst                       1
# Analytics engineer            1
#                              ..
# data engineer                 1
# iOS Developer                 1
# support engineer              1
# technical business analyst    1
# working student (QA)          1
# Name: Seniority level, Length: 144, dtype: int64

# %%
df1.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
min = df1.groupby('Your main technology / programming language')['Yearly brutto salary (without bonus and stocks) in EUR'].min()
max = df1.groupby('Your main technology / programming language')['Yearly brutto salary (without bonus and stocks) in EUR'].max()
avg = df1.groupby('Your main technology / programming language')['Yearly brutto salary (without bonus and stocks) in EUR'].mean()
print(min,max,avg)
# Out:
# Your main technology / programming language
# -                50000.0
# --               62000.0
# .NET             21120.0
# .Net             60000.0
# .Net, Angular    75000.0
#                   ...
# swift            75000.0
# typescript       88000.0
# yaml             65000.0
# Офмф             79000.0
# С#               88000.0
# Name: Yearly brutto salary (without bonus and stocks) in EUR, Length: 254, dtype: float64 Your main technology / programming language
# -                 50000.0
# --                62000.0
# .NET             115000.0
# .Net              99000.0
# .Net, Angular     75000.0
#                    ...
# swift             75000.0
# typescript        88000.0
# yaml              70000.0
# Офмф              79000.0
# С#                88000.0
# Name: Yearly brutto salary (without bonus and stocks) in EUR, Length: 254, dtype: float64 Your main technology / programming language
# -                50000.000000
# --               62000.000000
# ...

# %%
median = df1.groupby('Seniority level')['Yearly brutto salary (without bonus and stocks) in EUR'].median()
std = df1.groupby('Seniority level')['Yearly brutto salary (without bonus and stocks) in EUR'].std()

print(median, std)
# Out:
# Seniority level
# C-Level                                      150000.00
# C-level executive manager                    115000.00
# CTO                                          200000.00
# Director                                     100000.00
# Entry level                                   54179.13
# Head                                          93000.00
# Intern                                        35000.00
# Junior                                        48500.00
# Key                                           57000.00
# Lead                                          85000.00
# Manager                                       89200.00
# Middle                                        60000.00
# No level                                      55000.00
# No level                                      47500.00
# Principal                                     88500.00
# Self employed                                200000.00
# Senior                                        72000.00
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('Males:',(df1['Gender'] == 'Male').sum())
print('Females:',(df1['Gender'] == 'Female').sum())
# Out:
# Males: 1033
# Females: 187

# %% [markdown]
# - Answer (b)

# %%
seniority_distribution = df1.groupby(['City', 'Seniority level']).size().reset_index(name='Count')

# Display the result
print(seniority_distribution)
# Out:
#           City Seniority level  Count
# 0       Aachen          Junior      1
# 1       Aachen          Senior      1
# 2    Amsterdam          Junior      1
# 3    Amsterdam            Lead      1
# 4    Amsterdam          Middle      2
# ..         ...             ...    ...
# 191   Würzburg          Senior      1
# 192     Zurich          Middle      1
# 193     Zurich          Senior      3
# 194     Zürich          Intern      1
# 195     warsaw          Middle      1
#
# [196 rows x 3 columns]
